# %% [markdown]
# # Exploratory analysis
#
# This repo holds some example notebooks to get you started with exercises for the DataKind data science
# workshop in Mombasa.
#
# # Data
#
# Data used is as follows:
#
# 1. `./data/bongo-music-data.xlsx`
#
# A list of 40 Bongo tracks produced by prompting OpenAI's ChatGPT via Azure using model parameters:
#
# - Prompt: "List the top 50 bongo hits from Kenya in the last 20 years"
# - System message: "You are an AI assistant that helps people find information."
# - Model: gpt-3.5 turbo
# - Temperature: 0.7
# - Max response: 800
# - Top P: 0.95
#
# 2. Humanitarian Data Exchange Datasets for Kenya
#
# The following files were downloaded from the [Humanitarian Data Exchange](https://data.humdata.org/search?q=kenya&ext_search_source=main-nav)
#
# ```
# distribution-of-population-age-3-years-and-above-by-school-attendance-status-per-subcounty.xlsx
# distribution-of-population-by-sex-number-of-households-land-area-population-density-and-sub-cou.xlsx
# per-capita-food-consumption-2017-and-2018.xlsx
# retail-prices-for-dry-beans-2019.xlsx
# ```
#
#
# # Setup
#
# Package installations ...

# %%
# %pip install openpyxl==3.1.2
# %pip install pandas_profiling==3.6.6

# %%
import pandas as pd
import openpyxl

# %% [markdown]
# Now, let's read in our data ...

# %%
df = pd.read_excel('../data/bongo-music-data.xlsx')

# %% [markdown]
# # Analysis

# %%
display(df)
# Out:
#      Type                   Song  \
# 0   Bongo              Kwangwaru
# 1   Bongo                 Tetema
# 2   Bongo           Moyo Mashine
# 3   Bongo                 Nibebe
# 4   Bongo                 Kidogo
# 5   Bongo             Number One
# 6   Bongo             Hallelujah
# 7   Bongo          Nataka Kulewa
# 8   Bongo             Zigo Remix
# 9   Bongo             Utanipenda
# 10  Bongo              Kajiandae
# 11  Bongo                 Salome
# 12  Bongo           Kipenda Roho
# 13  Bongo                Nishike
# 14  Bongo  Mapenzi Yanarun Dunia
# 15  Bongo             Zilipendwa
# 16  Bongo                 Naomba
# 17  Bongo                Malaika
# 18  Bongo         Nataka Nimuone
# 19  Bongo       Nitakupwelepweta
# 20  Bongo                   Zigo
# 21  Bongo                  Mwana
# 22  Bongo                   Bado
# 23  Bongo                  Barua
# 24  Bongo          Nataka Kufika
# 25  Bongo                    Aje
# 26  Bongo                 Nibebe
# ...

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(df, title="Pandas Profiling Report")
profile.to_file("output.html")
# Out:
# /var/folders/6b/jxkmd4lx1nl8lc4sdpn0yz500000gn/T/ipykernel_4859/3038872191.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
